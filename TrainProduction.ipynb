# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import scipy
from scipy import stats
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
def WAPE(actual,predicted):
    sum_actual=sum(actual)
    diff=(abs(actual-predicted))
    final_diff=(sum(diff))/sum_actual
    return final_diff*100

# %%
t1 = pd.read_csv('TrainDataset.csv')
v1 = pd.read_csv('ValidateDataset.csv')

# %%
pro_actual_t = t1.Production
pro_actual_v = v1.Production

# %%
x_train = t1.drop(['Income','VotingAgeCitizen','Employed','PublicWork','Production'],axis='columns')
x_validate = v1.drop(['Income','VotingAgeCitizen','Employed','PublicWork','Production'],axis='columns')

# %%
model_Production= tf.keras.models.Sequential()
model_Production.add(tf.keras.layers.Dense(64, tf.keras.activations.relu, input_shape=[len(x_train.keys())]))
model_Production.add(tf.keras.layers.Dense(64, tf.keras.activations.relu))
model_Production.add(tf.keras.layers.Dense(64, tf.keras.activations.relu))
model_Production.add(tf.keras.layers.Dense(1, tf.keras.activations.linear))

# %%
model_Production.compile(optimizer='adam',loss='mean_squared_error',metrics=['mae'])

epoch=50

for i in range(1,31):
    
    model_Production.fit(x_train,pro_actual_t, batch_size=1024,epochs=epoch)

    train_ans = np.asarray(model_Production.predict(x_train)).reshape(-1,1)
    validate_ans = np.asarray(model_Production.predict(x_validate)).reshape(-1,1)

    fig,ax = plt.subplots()
    ax.scatter(pro_actual_t, train_ans)
    ax.plot([pro_actual_t.min(), pro_actual_t.max()], [pro_actual_t.min(), pro_actual_t.max()], 'k-', lw=4)
    ax.set_xlabel('Real Train')
    ax.set_ylabel('Predicted Train')
    plt.show()

    fig,ax = plt.subplots()
    ax.scatter(pro_actual_v, validate_ans)
    ax.plot([pro_actual_v.min(), pro_actual_v.max()], [pro_actual_v.min(), pro_actual_v.max()], 'k-', lw=4)
    ax.set_xlabel('Real Validate')
    ax.set_ylabel('Predicted Validate')
    plt.show()

    print(epoch*i)
    print("Train: ",WAPE(np.asarray(pro_actual_t).reshape(-1,1),train_ans))
    print("Validate: ",WAPE(np.asarray(pro_actual_v).reshape(-1,1),validate_ans))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 46539 samples
# Epoch 1/50
# 46539/46539 [==============================] - 1s 14us/sample - loss: 300595.7304 - mae: 342.7194
# Epoch 2/50
# 46539/46539 [==============================] - 0s 7us/sample - loss: 3246.2024 - mae: 42.5169
# Epoch 3/50
# 46539/46539 [==============================] - 0s 7us/sample - loss: 1089.2715 - mae: 24.3334
# Epoch 4/50
# 46539/46539 [==============================] - 0s 7us/sample - loss: 827.7576 - mae: 21.4554
# Epoch 5/50
# 46539/46539 [==============================] - 0s 7us/sample - loss: 678.0139 - mae: 19.5178
# Epoch 6/50
# 46539/46539 [==============================] - 0s 7us/sample - loss: 569.4394 - mae: 17.9378
# Epoch 7/50
# 46539/46539 [==============================] - 0s 7us/sample - loss: 480.5293 - mae: 16.5092
# Epoch 8/50
# ...

# %%
test_data=pd.read_csv("TestDataset.csv")

# %%
final_test = test_data.Production
d = test_data.drop(['Income','VotingAgeCitizen','Employed','PublicWork','Production'],axis='columns')
ans2 = np.asarray(model_Production.predict(d)).reshape(-1,1)
print("Test: ",WAPE(np.asarray(final_test).reshape(-1,1),ans2))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train:  [6.93099293]

# %%
#model_Production.save('Production-1.h5')
